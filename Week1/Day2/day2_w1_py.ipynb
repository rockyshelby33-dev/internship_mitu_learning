# %%
#day 2 string fun and other stuff

# %%
print("Hello World")
# Out:
# Hello World

# %%
#string functions

# %%
name = "Nitish"

# %%
name.lower()
# Out:
# 'nitish'

# %%
name.upper()
# Out:
# 'NITISH'

# %%
name.title()
# Out:
# 'Nitish'

# %%
# Out:
# 'NITISH'

# %%
name.islower()
# Out:
# True

# %%
name.istitle()
# Out:
# False

# %%
name.isupper()
# Out:
# False

# %%
####

# %%
name1 = "ok"
name2 = "123"
name3 = "ok123"

# %%
name1.isalpha()
# Out:
# True

# %%
name2.isalpha()
# Out:
# False

# %%
name3.isalpha()
# Out:
# False

# %%
name1.isdigit()
# Out:
# False

# %%
name2.isdigit()
# Out:
# True

# %%
name3.isdigit()
# Out:
# False

# %%
name2.isalnum()
# Out:
# True

# %%
name = " Pune "

# %%
print(name)
# Out:
#  Pune

# %%
name.startswith("P")
# Out:
# False

# %%
name.startswith(" P")
# Out:
# True

# %%
name.endswith("e")
# Out:
# False

# %%
name.endswith("e ")
# Out:
# True

# %%
name.endswith(" Pune ")
# Out:
# True

# %%
name
# Out:
# ' Pune '

# %%
name.rstrip()
# Out:
# ' Pune'

# %%
name.strip()
# Out:
# 'Pune'

# %%
name
# Out:
# ' Pune '

# %%
len(name)
# Out:
# 6

# %%
name.replace('u', 'oo')
# Out:
# ' Poone '

# %% [markdown]
# # Operators

# %%
#arithmetic

# %%
a = 5
b = 17

# %%
a + b
# Out:
# 22

# %%
a - b
# Out:
# -12

# %%
b/a ,b / a
# Out:
# (3.4, 3.4)

# %%
a * b
# Out:
# 85

# %%
a**b #raise to
# Out:
# 762939453125

# %%
a ** b
# Out:
# 762939453125

# %%
b // a #quotients Integer (no decimals or float value
# Out:
# 3

# %%
b % a
# Out:
# 2

# %%
#assignment opertors

# %%
u = 5 # =

# %%
u
# Out:
# 5

# %%
u = u + 3

# %%
u
# Out:
# 8

# %%
u += 3

# %%
u
# Out:
# 11

# %%
u -= 3 
u
# Out:
# 8

# %%
# comparison

# %%
a
# Out:
# 5

# %%
b
# Out:
# 17

# %%
a > b
# Out:
# False

# %%
a < b
# Out:
# True

# %%
a >= b
# Out:
# False

# %%
a <= b
# Out:
# True

# %%
a == b
# Out:
# False

# %%
a != b
# Out:
# True

# %%
#logical Operator

# %%
a = True
b = False

# %%
a and b
# Out:
# False

# %%
a or b
# Out:
# True

# %%
not a
# Out:
# False

# %%
not b
# Out:
# True

# %%
#identity operator -> is, is not

# %%
a = 5 
b = 5

# %%
id(a), id(b)
# Out:
# (140729625650216, 140729625650216)

# %%
a is b
# Out:
# True

# %%
a = [3, 4]
b = [3, 4]

# %%
a is b
# Out:
# False

# %%
a is not b
# Out:
# True

# %%
z = a #not good way , goofy ahh haha

# %%
z is a
# Out:
# True

# %%
z
# Out:
# [3, 4]

# %%
a.append(10)
a
# Out:
# [3, 4, 10]

# %%
z
# Out:
# [3, 4, 10]

# %%
# membership opertaors -> in

# %%
l = [4, 6, 19, 48]

# %%
6 in l
# Out:
# True

# %%
4 in l
# Out:
# True

# %%
2 in l
# Out:
# False

# %%
2 not in l
# Out:
# True

# %%
100 not in l
# Out:
# True

# %% [markdown]
# ## precedences and Association

# %%
#BODMAS

# %%
5 + 2 - 10
# Out:
# -3

# %%
(4 - 2) ** 2
# Out:
# 4

# %%
2 ** 2 ** 3
# Out:
# 256

# %%
2 ** 3 // 2
# Out:
# 4

# %%
#print funtion

# %%
name = "xyz"
marks = 76.57
print ("my name is ", name," and marks are", marks) # 1st way
# Out:
# my name is  xyz  and marks are 76.57

# %%
print("my name is %s and marks are %f" %(name, marks))
# Out:
# my name is xyz and marks are 76.570000

# %%
print(f"my name is {name} and marks are {marks}")
# Out:
# my name is xyz and marks are 76.57

# %%
# dir and help

# %%
dir(name)
# Out:
# ['__add__',
#  '__class__',
#  '__contains__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getnewargs__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mod__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__rmod__',
#  '__rmul__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'capitalize',
#  'casefold',
#  'center',
#  'count',
#  'encode',
#  'endswith',
#  'expandtabs',
#  'find',
#  'format',
#  'format_map',
#  'index',
#  'isalnum',
#  'isalpha',
#  'isascii',
#  'isdecimal',
#  'isdigit',
#  'isidentifier',
#  'islower',
#  'isnumeric',
#  'isprintable',
#  'isspace',
#  'istitle',
#  'isupper',
#  'join',
#  'ljust',
#  'lower',
#  'lstrip',
#  'maketrans',
#  'partition',
#  'removeprefix',
# ...

# %%
help(name.strip)# help for a func
# Out:
# Help on built-in function strip:
#
# strip(chars=None, /) method of builtins.str instance
#     Return a copy of the string with leading and trailing whitespace removed.
#
#     If chars is given and not None, remove characters in chars instead.

# %%
#ascii

# %%
ord("a")
# Out:
# 97

# %%
ord("A")
# Out:
# 65

# %%
chr(65)
# Out:
# 'A'

# %%
chr(111217)
# Out:
# '𛉱'

# %%
#type casting

# %%
num1 = 34
num2 = 44.213
num3 = "ok"

# %%
type[(num1),(num2),(num3)]
# Out:
# type[34, 44.213, 'ok']

# %%
float(num1)
# Out:
# 34.0

# %%
int(num2)
# Out:
# 44

# %%
str(num2)
# Out:
# '44.213'

# %%
str(num1)
# Out:
# '34'

# %%
int(num3)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[179], line 1
# ----> 1 int(num3)
#
# ValueError: invalid literal for int() with base 10: 'ok'

# %%
# user input

# %%
a = input("Enter the number")
# Out:
# Enter the number 2

# %%
print (a)
# Out:
# 2

# %%
e = int(input("enter the num1 "))
f = int(input("enter the num2 "))
res = e + f
print(" addition is ", res)
# Out:
# enter the num1  21
# enter the num2  23
#  addition is  44

# %%
t = int(input("Enter the seconds"))
hours = t // 3600
minutes = (t % 3600) // 60
seconds = t % 60
print(hours,':', minutes,':', seconds) 
# task is get user input in sec and output should be in hour:min:sec
# Out:
# Enter the seconds 1234
# 0 : 20 : 34

# %%
# Out:
# Help on int object:
#
# class int(object)
#  |  int([x]) -> integer
#  |  int(x, base=10) -> integer
#  |
#  |  Convert a number or string to an integer, or return 0 if no arguments
#  |  are given.  If x is a number, return x.__int__().  For floating-point
#  |  numbers, this truncates towards zero.
#  |
#  |  If x is not a number or if base is given, then x must be a string,
#  |  bytes, or bytearray instance representing an integer literal in the
#  |  given base.  The literal can be preceded by '+' or '-' and be surrounded
#  |  by whitespace.  The base defaults to 10.  Valid bases are 0 and 2-36.
#  |  Base 0 means to interpret the base from the string as an integer literal.
#  |  >>> int('0b100', base=0)
#  |  4
#  |
#  |  Built-in subclasses:
#  |      bool
#  |
#  |  Methods defined here:
#  |
#  |  __abs__(self, /)
#  |      abs(self)
#  |
#  |  __add__(self, value, /)
#  |      Return self+value.
#  |
#  |  __and__(self, value, /)
#  |      Return self&value.
#  |
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[195], line 1
# ----> 1 calender(now)
#
# NameError: name 'calender' is not defined
