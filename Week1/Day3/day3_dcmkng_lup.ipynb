# %%
pwd
# Out:
# 'C:\\Users\\shrey\\Internship_learning\\Week1\\Day3'

# %%
num = int(input("Enter The No."))

if num > 5:
    print('yes')
# Out:
# Enter The No. 6
# yes

# %%
num = int(input("Enter the No."))
if num > 5:
    print('yes')
else:
    print('no')
# Out:
# Enter the No. 5
# no

# %%
num = int(input("ENter no"))
if num > 0:
    print("Positive")
elif num == 0: 
    print("Zero")
else:
    print("Negative")
# Out:
# ENter no 32
# Positive

# %%
num2 = int(input("ENter th no"))

if num2 % 2 == 0:
    print("Even")
else:
    print("Odd")
# Out:
# ENter th no 21
# Odd

# %%
int(True)
# Out:
# 1

# %%
int(False)
# Out:
# 0

# %%
True + True + False + True
# Out:
# 3

# %%
a = 1 
if a:
    print('Exists')
# Out:
# Exists

# %%
no = int(input("Enter the no"))# nestif
if no >= 51:
    if no < 100:
        print (" Yes, in between ")
    else:
        print("Nope, not in between 50-100")
else: 
    print("Nope, not in between 50-100")
# Out:
# Enter the no 50
# Nope, not in between 50-100

# %%
#logicall
no = int(input("Enter the no"))
if no >= 50 and no <= 100:
    print("Yes, in between 50-100")
else:
    print("Nope, not in between 50-100")
# Out:
# Enter the no 51
# Yes, in between 50-100

# %%
pc = int(input("ENter the purchase cost"))
sc = int(input("Enter the selling cost"))
profit = sc - pc
loss = pc - sc
if  profit > 0:
    print ("profit is",profit)
else:
    print("loss is",loss)
# Out:
# ENter the purchase cost 24
# Enter the selling cost 21
# loss is 3

# %%
year = int(input("Enter the Year"))
if year % 4 == 0:
    if year % 100 == 0:
        if year % 400 == 0:
            print("its a LEAP YEAR")
        else:
            print("not a leap year")
    else:
        print("It's a LEAP YEAR")
else:
    print("not a leap ")
# Out:
# Enter the Year 2024
# It's a LEAP YEAR

# %%
num1 = int(input("Enter no1: "))
num2 = int(input("Enter no2: "))
num3 = int(input("Enter no3: "))
if num1 >= num2:
    if num1 >= num3:
        print("num1 is the largest")
    else:
        print("num3 is the largest")
else:
    if num2 >= num3:
        print("num2 is the largest")
    else:
        print("num3 is the largest")
# Out:
# Enter no1:  21
# Enter no2:  23
# Enter no3:  234
# num3 is the largest

# %%
#menu driven 
print("WELCOME TO THE Simple CALCULATOR")

num = int(input("ENTER THE NUMBER"))

print("Menu=>\n1. Sqauare\n2. Cube\n3. Check +ve or -ve")

ch = int(input("Select your Choice "))

if ch == 1:
    print(num * num)
elif ch == 2:
    print(num ** 3)
elif ch == 3:
    if num > 0:
        print("Positive")
    elif num == 0: 
        print("Zero")
    else:
        print("Negative")
else:
    print("Please enter the valid option /choice ")
# Out:
# WELCOME TO THE Simple CALCULATOR
# ENTER THE NUMBER 10
# Menu=>
# 1. Sqauare
# 2. Cube
# 3. Check +ve or -ve
# Select your Choice  2
# 1000

# %%
my_string = input("Enter a string: ")

while True:
    print("\n--- STRING MANIPULATION MENU ---")
    print("1. Convert to UPPERCASE")
    print("2. Convert to lowercase")
    print("3. Replace a part of the string")
    print("4. Exit")
    
    choice = input("Enter your choice (1/2/3/4): ")
    
 
    if choice == '1':
        print("\nResult:", my_string.upper())
        
    elif choice == '2':
        print("\nResult:", my_string.lower())
        
    elif choice == '3':

        target = input("Enter the part you want to replace: ")
        replacement = input(f"Enter what you want to replace '{target}' with: ")
        
        my_string = my_string.replace(target, replacement)
        print("\nResult:", my_string)
        
    elif choice == '4':
        print("\nExiting program. Goodbye!")
        break
        
    else:
        print("\nInvalid choice! Please enter 1, 2, 3, or 4.")
# Out:
# Enter a string:  shreyo
# --- STRING MANIPULATION MENU ---
# 1. Convert to UPPERCASE
# 2. Convert to lowercase
# 3. Replace a part of the string
# 4. Exit
# Enter your choice (1/2/3/4):  3
# Enter the part you want to replace:  yo
# Enter what you want to replace 'yo' with:  yas
# Result: shreyas
#
# --- STRING MANIPULATION MENU ---
# 1. Convert to UPPERCASE
# 2. Convert to lowercase
# 3. Replace a part of the string
# 4. Exit
# Enter your choice (1/2/3/4):  4
# Exiting program. Goodbye!
