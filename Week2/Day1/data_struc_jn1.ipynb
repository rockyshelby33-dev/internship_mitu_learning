# %% [markdown]
# ## DATA STRUCTURES :LIST

# %%
l = [23,45,546,654]

# %%
print(l)
# Out:
# [23, 45, 546, 654]

# %%
l1 = [45,23,85,58.43555,'python','shre',392]

# %%
l1
# Out:
# [45, 23, 85, 58.43555, 'python', 'shre', 392]

# %%
l1[4]
# Out:
# 'python'

# %%
l1[-3]
# Out:
# 'python'

# %%
l1[1] = 100

# %%
l1[1]
# Out:
# 100

# %%
l1
# Out:
# [45, 100, 85, 58.43555, 'python', 'shre', 392]

# %%
l1[-3] = True #replace java with any boolean value

# %%
l1
# Out:
# [45, 100, 85, 58.43555, True, 'shre', 392]

# %%
#list slicing

# %%
l = [21,23,45,435,445,1110]

# %%
l
# Out:
# [21, 23, 45, 435, 445, 1110]

# %%
l[1:4]
# Out:
# [23, 45, 435]

# %%
l[1:-2]
# Out:
# [23, 45, 435]

# %%
l[0:6:2] #slicing with steps
# Out:
# [21, 45, 445]

# %%
l[::2]## alternate method(without using the index)
# Out:
# [21, 45, 445]

# %%
l[0:6:-1]
# Out:
# []

# %%
    l[::-1]
# Out:
# [1110, 445, 435, 45, 23, 21]

# %%
l[1:4] = [100,450,500]

# %%
l
# Out:
# [21, 100, 450, 500, 445, 1110]

# %%
l1
# Out:
# [45, 100, 85, 58.43555, True, 'shre', 392]

# %%
del l1[-2]
l1
# Out:
# [45, 100, 85, 58.43555, True, 392]

# %%
del l1

# %%
l1
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[45], line 1
# ----> 1 l1
#
# NameError: name 'l1' is not defined

# %%
#membership operator

# %%
l
# Out:
# [21, 100, 450, 500, 445, 1110]

# %%
445 in l
# Out:
# True

# %%
3945 in l
# Out:
# False

# %%
l * 2
# Out:
# [21, 100, 450, 500, 445, 1110, 21, 100, 450, 500, 445, 1110]

# %%
'ok' * 3 #string reptition
# Out:
# 'okokok'

# %%
l + [60,70,80] #concatenation of list
# Out:
# [21, 100, 450, 500, 445, 1110, 60, 70, 80]

# %%
l2 = [30,50,70]
l3 = [20,40,60]

# %%
l2 + l3
# Out:
# [30, 50, 70, 20, 40, 60]

# %%
for num in l:
    print(num ** 2)
# Out:
# 441
# 10000
# 202500
# 250000
# 198025
# 1232100

# %%
for i in l:
    if i % 2 != 0:
        print(i, end = ' ')
# Out:
# 21 445

# %%
# list comprehension

# %%
new1 = [i**2 for i in l]

# %%
new1
# Out:
# [441, 10000, 202500, 250000, 198025, 1232100]

# %%
newl2
# Out:
#   Cell In[69], line 1
#     newl2 = [l for i in
#                         ^
# _IncompleteInputError: incomplete input

# %%
names = ['ayr', 'athrv','samu', 'swaraj', 'Sukanya', 'shivraj']

# %%
names
# Out:
# ['ayr', 'athrv', 'samu', 'swaraj', 'sukanya', 'shivraj']

# %%
for i in names:
    if i.lower().startswith('s'):
        print(i)
# Out:
# samu
# swaraj
# sukanya
# shivraj

# %%
#functions

# %%
l
# Out:
# [21, 100, 450, 500, 445, 1110]

# %%
len(l)
# Out:
# 6

# %%
max(l)
# Out:
# 1110

# %%
min(l)
# Out:
# 21

# %%
sorted(l)
# Out:
# [21, 100, 445, 450, 500, 1110]

# %%
sorted(l, reverse = True)
# Out:
# [1110, 500, 450, 445, 100, 21]

# %%
#append

# %%
l
# Out:
# [21, 100, 450, 500, 445, 1110]

# %%
l.append(2000)

# %%
l
# Out:
# [21, 100, 450, 500, 445, 1110, 2000]

# %%
##missing:(

# %%
#insert

# %%
l
# Out:
# [21, 100, 450, 500, 445, 1110, 2000]

# %%
l.insert(1,77)
l
# Out:
# [21, 77, 100, 450, 500, 445, 1110, 2000]

# %%
l.remove(77)

# %%
l
# Out:
# [21, 100, 450, 500, 445, 1110, 2000]

# %%
l.pop()
l
# Out:
# [21, 100, 450, 500, 445, 1110]

# %%
l.pop(3)
# Out:
# 500

# %%
l
# Out:
# [21, 100, 450, 445, 1110]

# %%
l.index(100)
# Out:
# 1

# %%
l.sort(reverse = True)
l
# Out:
# [1110, 450, 445, 100, 21]
