# %%
print('Hello World')
# Out:
# Hello World

# %% [markdown]
# # Identifiers

# %%
num = 31

# %%
num1 = 21

# %%
name = "Rushikesh"

# %%
print(name)
# Out:
# Rushikesh

# %%
name
# Out:
# 'Rushikesh'

# %%
rate of interest = 5 #not to do
# Out:
#   Cell In[7], line 1
#     rate of interest = 5 #not to do
#          ^
# SyntaxError: invalid syntax

# %%
rate_of_interest = 5

# %%
rate_of_interest
# Out:
# 5

# %%
pass = 5 #not to do
# Out:
#   Cell In[11], line 1
#     pass = 5 #not to do
#          ^
# SyntaxError: invalid syntax

# %%
Pass = 5 
print(Pass)
# Out:
# 5

# %% [markdown]
# # Data types and Data Structures

# %%
num3 = 11
num4 = 3489.4985
name = "michael"

# %%
type(num3)
# Out:
# int

# %%
type(num4)
# Out:
# float

# %%
type(name)
# Out:
# str

# %%
num5 = 1000000000 ** 128

# %%
print(num5)
# Out:
# ...

# %%
les = 'I like Python Programming '

# %%
print(les)
# Out:
# I like Python Programming

# %%
les1 = 'I Like "Python" Programming'
print(les1)
# Out:
# I Like "Python" Programming

# %%
#sample addition program

# %%
a = 3
b = 5
z = a + b
print(z)
# Out:
# 8

# %%
a = 3;b = 9; z = a + b; print(z);
# Out:
# 12

# %%
a, b, c = 23,56, "ok"

# %%
a
# Out:
# 23

# %%
b
# Out:
# 56

# %%
c
# Out:
# 'ok'
